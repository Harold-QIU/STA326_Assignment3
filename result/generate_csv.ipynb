# %%
import pandas as pd

# Data for each epoch
data = {
    "Epoch": list(range(50)),
    "Loss": [
        0.354, 0.304, 0.287, 0.278, 0.274, 0.273, 0.272, 0.271, 0.270, 0.270,
        0.269, 0.269, 0.269, 0.268, 0.268, 0.268, 0.268, 0.268, 0.267, 0.267,
        0.267, 0.267, 0.267, 0.267, 0.267, 0.267, 0.266, 0.267, 0.266, 0.266,
        0.266, 0.266, 0.266, 0.266, 0.266, 0.266, 0.266, 0.266, 0.266, 0.266,
        0.266, 0.266, 0.266, 0.266, 0.266, 0.265, 0.265, 0.265, 0.265, 0.266
    ],
    "HR": [
        0.529, 0.576, 0.604, 0.616, 0.619, 0.628, 0.623, 0.631, 0.634, 0.632,
        0.633, 0.632, 0.634, 0.629, 0.632, 0.634, 0.635, 0.636, 0.636, 0.634,
        0.634, 0.635, 0.634, 0.633, 0.633, 0.636, 0.635, 0.636, 0.638, 0.638,
        0.638, 0.638, 0.639, 0.640, 0.638, 0.637, 0.638, 0.639, 0.638, 0.633,
        0.638, 0.639, 0.642, 0.641, 0.638, 0.638, 0.641, 0.639, 0.640, 0.637
    ],
    "NDCG": [
        0.294, 0.324, 0.344, 0.352, 0.356, 0.358, 0.359, 0.363, 0.364, 0.365,
        0.364, 0.366, 0.368, 0.365, 0.365, 0.365, 0.365, 0.367, 0.366, 0.367,
        0.367, 0.369, 0.367, 0.367, 0.367, 0.369, 0.367, 0.369, 0.369, 0.368,
        0.369, 0.369, 0.369, 0.370, 0.369, 0.369, 0.370, 0.370, 0.369, 0.366,
        0.369, 0.369, 0.371, 0.370, 0.369, 0.369, 0.371, 0.369, 0.369, 0.367
    ]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
file_path = '50Epoch-GMF.csv'
df.to_csv(file_path, index=False)

# %%
# Data for each epoch of the MLP model
mlp_data = {
    "Epoch": list(range(50)),
    "Loss": [
        0.344, 0.303, 0.284, 0.274, 0.267, 0.262, 0.258, 0.255, 0.252, 0.250,
        0.248, 0.246, 0.245, 0.243, 0.242, 0.241, 0.241, 0.240, 0.239, 0.238,
        0.237, 0.237, 0.236, 0.235, 0.235, 0.235, 0.234, 0.234, 0.233, 0.233,
        0.232, 0.232, 0.232, 0.231, 0.231, 0.231, 0.231, 0.230, 0.230, 0.230,
        0.229, 0.230, 0.229, 0.229, 0.229, 0.229, 0.228, 0.228, 0.228, 0.228
    ],
    "HR": [
        0.528, 0.580, 0.612, 0.625, 0.642, 0.652, 0.650, 0.655, 0.657, 0.658,
        0.659, 0.664, 0.671, 0.664, 0.663, 0.670, 0.673, 0.664, 0.669, 0.666,
        0.668, 0.670, 0.671, 0.673, 0.671, 0.669, 0.672, 0.665, 0.669, 0.670,
        0.666, 0.663, 0.664, 0.672, 0.671, 0.665, 0.662, 0.666, 0.667, 0.665,
        0.668, 0.671, 0.666, 0.666, 0.668, 0.665, 0.671, 0.670, 0.664, 0.667
    ],
    "NDCG": [
        0.293, 0.328, 0.353, 0.360, 0.373, 0.380, 0.380, 0.386, 0.386, 0.389,
        0.391, 0.392, 0.393, 0.391, 0.390, 0.395, 0.395, 0.391, 0.396, 0.394,
        0.395, 0.395, 0.397, 0.400, 0.396, 0.398, 0.398, 0.397, 0.399, 0.398,
        0.393, 0.395, 0.395, 0.399, 0.399, 0.395, 0.393, 0.394, 0.396, 0.395,
        0.396, 0.397, 0.394, 0.396, 0.396, 0.395, 0.401, 0.397, 0.399, 0.396
    ]
}

# Creating a DataFrame for MLP
mlp_df = pd.DataFrame(mlp_data)

# Save the DataFrame to a CSV file
mlp_file_path = '50Epoch-MLP.csv'
mlp_df.to_csv(mlp_file_path, index=False)

# %%
import pandas as pd

# Data for each epoch of the NeuMF-end model
neumf_data = {
    "Epoch": list(range(50)),
    "Loss": [
        0.317, 0.274, 0.264, 0.259, 0.256, 0.253, 0.250, 0.248, 0.245, 0.243,
        0.241, 0.240, 0.239, 0.237, 0.236, 0.235, 0.234, 0.233, 0.232, 0.231,
        0.230, 0.230, 0.229, 0.228, 0.228, 0.227, 0.227, 0.226, 0.226, 0.225,
        0.225, 0.224, 0.224, 0.224, 0.224, 0.223, 0.223, 0.223, 0.222, 0.222,
        0.222, 0.222, 0.221, 0.221, 0.221, 0.221, 0.220, 0.221, 0.220, 0.220
    ],
    "HR": [
        0.601, 0.640, 0.652, 0.656, 0.663, 0.669, 0.673, 0.674, 0.678, 0.676,
        0.675, 0.678, 0.679, 0.684, 0.680, 0.680, 0.675, 0.674, 0.683, 0.680,
        0.676, 0.678, 0.677, 0.679, 0.677, 0.682, 0.674, 0.680, 0.677, 0.674,
        0.680, 0.676, 0.675, 0.678, 0.675, 0.679, 0.681, 0.675, 0.681, 0.679,
        0.678, 0.683, 0.677, 0.677, 0.680, 0.677, 0.676, 0.683, 0.675, 0.670
    ],
    "NDCG": [
        0.343, 0.366, 0.377, 0.382, 0.385, 0.389, 0.395, 0.399, 0.401, 0.402,
        0.402, 0.404, 0.407, 0.408, 0.405, 0.403, 0.402, 0.400, 0.407, 0.404,
        0.404, 0.403, 0.405, 0.406, 0.403, 0.407, 0.399, 0.403, 0.401, 0.405,
        0.401, 0.401, 0.400, 0.403, 0.399, 0.403, 0.403, 0.403, 0.404, 0.403,
        0.403, 0.406, 0.401, 0.402, 0.404, 0.403, 0.400, 0.404, 0.402, 0.399
    ]
}

# Creating a DataFrame for NeuMF-end
neumf_df = pd.DataFrame(neumf_data)

# Save the DataFrame to a CSV file
neumf_file_path = '50Epoch-NeuMF-end.csv'
neumf_df.to_csv(neumf_file_path, index=False)
